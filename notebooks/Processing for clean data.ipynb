# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv("https://raw.githubusercontent.com/daggeraile/market_clustering/master/raw_data/marketing_data.csv")

# %%
data.rename(columns={' Income ': 'Income'}, inplace=True)

# %%
data[['Income']].apply(lambda x: x[1:-1])
# Out:
#            Income
# 1     $57,091.00
# 2     $67,267.00
# 3     $32,474.00
# 4     $21,474.00
# 5     $71,691.00
# ...           ...
# 2234  $78,901.00
# 2235  $66,476.00
# 2236  $31,056.00
# 2237  $46,310.00
# 2238  $65,819.00
#
# [2238 rows x 1 columns]

# %%
data['Income'].fillna('$0.00 ', inplace=True)
data['Income'] = data['Income'].apply(lambda x: int(x[1:-4].replace(',','')))

# %%
data['Income'] = data['Income'].apply(lambda x: float(x))

# %%
data['Income'].sort_values()
# Out:
# 134          0.0
# 1213         0.0
# 262          0.0
# 1096         0.0
# 1858         0.0
#           ...
# 2204    157243.0
# 853     157733.0
# 497     160803.0
# 731     162397.0
# 527     666666.0
# Name: Income, Length: 2240, dtype: float64

# %%
data['Income'] = data['Income'].replace(0, np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data['Dt_Customer'] = pd.to_datetime(data['Dt_Customer'], format="%m/%d/%y")

# %%
data['Dt_Customer']
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-05-11
# 4      2014-04-08
#           ...
# 2235   2013-03-07
# 2236   2013-01-22
# 2237   2012-12-03
# 2238   2012-11-29
# 2239   2012-09-01
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
from dateutil import parser

# %%
parser.parse("12-01-2020", dayfirst='False')
# Out:
# datetime.datetime(2020, 1, 12, 0, 0)

# %%
data.to_csv("../raw_data/data.csv", index=False)

# %%
pd.read_csv("../raw_data/data.csv")
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...
